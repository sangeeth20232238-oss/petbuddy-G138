# %%
from google.colab  import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data1 =pd.read_csv("/content/drive/MyDrive/AI chat bot/data set /NEW DATA SET /data 1.csv")

# %%
print(data1.head())
# Out:
#   AnimalName symptoms1             symptoms2 symptoms3    symptoms4  \
# 0        Dog     Fever              Diarrhea  Vomiting  Weight loss
# 1        Dog     Fever              Diarrhea  Coughing    Tiredness
# 2        Dog     Fever              Diarrhea  Coughing     Vomiting
# 3        Dog     Fever  Difficulty breathing  Coughing     Lethargy
# 4        Dog     Fever              Diarrhea  Coughing     Lethargy
#
#      symptoms5 Dangerous
# 0  Dehydration       Yes
# 1        Pains       Yes
# 2     Anorexia       Yes
# 3     Sneezing       Yes
# 4     Blue Eye       Yes

# %%
data1["AnimalName"] = data1["AnimalName"].astype(str).str.strip().str.lower()

# %%
data1=data1[data1["AnimalName"]=="dog"]

# %%
data1=data1.dropna()

# %%
data1=data1.drop_duplicates()

# %%
data1 = data1.drop('Dangerous', axis=1)

# %%
print(data1.head())
# Out:
#   AnimalName symptoms1             symptoms2 symptoms3    symptoms4  \
# 0        dog     Fever              Diarrhea  Vomiting  Weight loss
# 1        dog     Fever              Diarrhea  Coughing    Tiredness
# 2        dog     Fever              Diarrhea  Coughing     Vomiting
# 3        dog     Fever  Difficulty breathing  Coughing     Lethargy
# 4        dog     Fever              Diarrhea  Coughing     Lethargy
#
#      symptoms5
# 0  Dehydration
# 1        Pains
# 2     Anorexia
# 3     Sneezing
# 4     Blue Eye

# %%
data1.to_csv("/content/drive/MyDrive/AI chat bot/data set /NEW DATA SET /Cleaned data sets new_cleaned_data1.csv",index=False)
